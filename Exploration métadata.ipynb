# %% [markdown]
# ### 1er dossier d'exploration des fichiers (certains codes sont brouillons mais ont été rattrapés dans d'autres fichiers)

# %% [markdown]
# ### Importation des librairies :

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import requests

# %%
import os

# %% [markdown]
# ### Importation des métadata pour la compréhension des DataFrames :

# %%
metadat_mob = pd.read_excel("Mobilisations Metadata.xlsx")
display(metadat_mob)
metadat_mob.info()
# Out:
#                       Column            Sample record  \
# 0             IncidentNumber          000008-01012018
# 1                    CalYear                     2018
# 2                 HourOfCall                        3
# 3     ResourceMobilisationId                  5055153
# 4              Resource_Code                     A392
# 5       PerformanceReporting                        1
# 6       DateAndTimeMobilised      01/01/2018 00:04:25
# 7          DateAndTimeMobile      01/01/2018 00:05:38
# 8         DateAndTimeArrived      01/01/2018 00:10:13
# 9         TurnoutTimeSeconds                       73
# 10         TravelTimeSeconds                      275
# 11     AttendanceTimeSeconds                      348
# 12           DateAndTimeLeft      01/01/2018 00:16:38
# 13       DateAndTimeReturned      2018-01-01 00:22:45
# 14  DeployedFromStation_Code                      A39
# 15  DeployedFromStation_Name                 Finchley
# ...

# %%
metadat = pd.read_excel("Metadata.xlsx")
display(metadat)
metadat.info()
# Out:
#                                     Column         Sample record  \
# 0                           IncidentNumber       000008-01012018
# 1                               DateOfCall   2018-01-01 00:00:00
# 2                                  CalYear                  2018
# 3                               TimeOfCall              00:04:25
# 4                               HourOfCall                     0
# 5                            IncidentGroup           False Alarm
# 6                      StopCodeDescription                   AFA
# 7                       SpecialServiceType                   NaN
# 8                         PropertyCategory       Non Residential
# 9                             PropertyType               Mosque
# 10                        AddressQualifier  Within same building
# 11                           Postcode_full                N2 8AY
# 12                       Postcode_district                    N2
# ...

# %% [markdown]
# #### Création d'un tableau pour comprendre à quoi correspondent les codes retard :

# %%
ID_retard = LFB_mob[['DelayCodeId','DelayCode_Description']].drop_duplicates()
print(ID_retard)
# Out:
#                 DelayCodeId               DelayCode_Description
# IncidentNumber
# 235138081               NaN                                 NaN
# 8091                   12.0                         Not held up
# 17091                   5.0            Address incomplete/wrong
# 49091                   9.0             Traffic, roadworks, etc
# 107091                  8.0            Traffic calming measures
# 158091                  7.0  Arrived but held up - Other reason
# 171091                  6.0          Appliance/Equipment defect
# 181091                 11.0   Mob/Radio problems when mobilised
# 310091                 13.0      On outside duty when mobilised
# 1336091                10.0                  Weather conditions
# 2868091                 3.0            At drills when mobilised

# %% [markdown]
# La méthode '.unique()' a été appliquée à toutes les variables du dataframe dans le but d'observer les variables avec peu de valeur unique.

# %%
#LFB_incident['NumCalls'].unique()
# Méthode .unique() utilisée avec toutes les variables des deux dataframes
# dans l'objectif d'évaluer la distribution des valeurs
